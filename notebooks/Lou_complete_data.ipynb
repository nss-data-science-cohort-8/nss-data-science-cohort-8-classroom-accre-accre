# %%
import pandas as pd
import re
from datetime import datetime as dt
import numpy as np
import matplotlib.pyplot as plt

# %%
jobs = pd.read_csv('../data/complete.csv')
jobs['END'] = pd.to_datetime(jobs['END'])
jobs.sort_values('END')
# Out:
#             JOBID      STATE  COMPLETE                BEGIN  \
# 6620848  24460577  COMPLETED         1  2020-10-01 00:05:55
# 6620906  24460647  COMPLETED         1  2020-10-01 00:10:38
# 6620898  24460639  COMPLETED         1  2020-10-01 00:11:22
# 6620922  24460668  COMPLETED         1  2020-10-01 00:15:16
# 6620925  24460671  COMPLETED         1  2020-10-01 00:17:08
# ...           ...        ...       ...                  ...
# 923388   32923987  COMPLETED         1  2021-10-07 20:09:26
# 923389   32923988  COMPLETED         1  2021-10-07 20:15:05
# 923390   32923989  COMPLETED         1  2021-10-07 20:24:26
# 1486117  32923996  COMPLETED         1  2021-10-07 20:31:08
# 1486118  32923997  COMPLETED         1  2021-10-07 20:39:26
#
#                         END  REQMEM Mc_Mn  USEDMEM  DIFFMEM     REQTIME  \
# 6620848 2020-10-01 00:10:15    4096    Mc   868.77  3227.23    12:00:00
# 6620906 2020-10-01 00:12:58    2000    Mn     0.09  1999.91  2-00:00:00
# ...

# %%
jobs_ce = jobs.loc[(jobs['END'] >= '2020-10-18') & (jobs['END'] <= '2021-10-06')].sort_values(by = 'END')
jobs_ce
# Out:
#                JOBID      STATE  COMPLETE                BEGIN  \
# 7027433     25022413  COMPLETED         1  2020-10-17 06:09:28
# 7032614     25036127  COMPLETED         1  2020-10-17 22:56:28
# 7032576     25036089  COMPLETED         1  2020-10-17 22:50:55
# 7033395     25038326  COMPLETED         1  2020-10-17 23:37:30
# 7032618     25036131  COMPLETED         1  2020-10-17 23:01:44
# ...              ...        ...       ...                  ...
# 923028      32919175  COMPLETED         1  2021-10-05 23:45:35
# 920870   32906933_72  COMPLETED         1  2021-10-02 17:11:56
# 920867   32906933_69  COMPLETED         1  2021-10-02 17:11:56
# 920869   32906933_71  COMPLETED         1  2021-10-02 17:11:56
# 923029      32919196  COMPLETED         1  2021-10-05 23:57:35
#
#                         END  REQMEM Mc_Mn   USEDMEM   DIFFMEM     REQTIME  \
# 7027433 2020-10-18 00:00:19   30720    Mn  13367.83  17352.17  6-00:00:00
# ...

# %%
filtered_jobs = jobs_ce[jobs_ce['END'].dt.date == pd.to_datetime('2020-10-18').date()]
filtered_jobs
# Out:
#                 JOBID      STATE  COMPLETE                BEGIN  \
# 7027433      25022413  COMPLETED         1  2020-10-17 06:09:28
# 7032614      25036127  COMPLETED         1  2020-10-17 22:56:28
# 7032576      25036089  COMPLETED         1  2020-10-17 22:50:55
# 7033395      25038326  COMPLETED         1  2020-10-17 23:37:30
# 7032618      25036131  COMPLETED         1  2020-10-17 23:01:44
# ...               ...        ...       ...                  ...
# 7037249      25046420  COMPLETED         1  2020-10-18 16:57:23
# 7042014      25051345  COMPLETED         1  2020-10-18 23:59:16
# 7041987      25051228  COMPLETED         1  2020-10-18 22:57:41
# 7030335  25032600_766  COMPLETED         1  2020-10-18 10:46:12
# 7042072      25051963  COMPLETED         1  2020-10-18 23:58:16
#
#                         END  REQMEM Mc_Mn   USEDMEM   DIFFMEM     REQTIME  \
# 7027433 2020-10-18 00:00:19   30720    Mn  13367.83  17352.17  6-00:00:00
# ...

# %%
jobs_ce.loc[(jobs_ce['END'] >= '2020-10-18 06:16:25') & (jobs_ce['END'] <= '2020-10-18 06:54:04')]
# Out:
#                JOBID      STATE  COMPLETE                BEGIN  \
# 7034426     25041648  COMPLETED         1  2020-10-18 05:57:15
# 7021299     25007342  COMPLETED         1  2020-10-16 18:27:44
# 7034547     25041921  COMPLETED         1  2020-10-18 06:17:35
# 7032880     25036718  COMPLETED         1  2020-10-17 21:30:22
# 7029585  25032600_16  COMPLETED         1  2020-10-17 16:47:50
# ...              ...        ...       ...                  ...
# 7034448     25041700  COMPLETED         1  2020-10-18 06:52:50
# 7034447     25041697  COMPLETED         1  2020-10-18 06:52:50
# 7024467     25012517  COMPLETED         1  2020-10-16 21:36:43
# 7034416     25041602  COMPLETED         1  2020-10-18 06:31:59
# 7034413     25041598  COMPLETED         1  2020-10-18 06:31:59
#
#                         END  REQMEM Mc_Mn  USEDMEM   DIFFMEM     REQTIME  \
# 7034426 2020-10-18 06:16:36   61440    Mn  4479.47  56960.53  5-00:00:00
# ...

# %%
ce5 = pd.read_csv('../data/ce5_unresponsive.csv')
ce5['END'] = pd.to_datetime(ce5['END']).dt.floor('s')

# %%
ce6 = pd.read_csv('../data/ce6_unresponsive.csv')
ce6['END'] = pd.to_datetime(ce6['END']).dt.floor('s')

# %%
ce_concat= pd.concat([ce5, ce6])
ce_concat.sort_values('END')
# Out:
#                      END  USER  RETRY       TIME  RETURNCODE  \
# 0    2020-10-18 06:16:25  9204      0  20.037672         1.0
# 1    2020-10-18 06:38:44  9204      0  20.038736         1.0
# 0    2020-10-18 06:53:44  9204      0  20.038464         1.0
# 1    2020-10-18 06:54:04  9204      1  20.048906         1.0
# 2    2020-10-18 07:47:25  9204      0  20.082628         1.0
# ...                  ...   ...    ...        ...         ...
# 1807 2021-09-24 18:14:35  9204      0  20.041436         1.0
# 1808 2021-09-24 19:13:14  9204      0  20.051321         1.0
# 1809 2021-10-02 08:14:16  9204      0  19.083227         1.0
# 1810 2021-10-02 18:29:08  9204      0  20.043146         1.0
# 1484 2021-10-06 15:39:20  9204      0  19.047097         1.0
#
#                                                 COMMAND
# 0     ['/usr/bin/sbatch', '/tmp/condor_g_scratch.0x5...
# 1     ['/usr/bin/sbatch', '/tmp/condor_g_scratch.0x5...
# 0     ['/usr/bin/sbatch', '/tmp/condor_g_scratch.0x5...
# ...
